# %%
""" print("Hello WOrld")
class Student:
    def __init__(self,name,RollNo,Branch):
        self.name=name
        self.RollNo=RollNo
        self.Branch=Branch
    def Method(self):
        print("The Name of the Student is ",self.name)
        print("The Student Roll Number is ",self.RollNo)
        print("The Student Branch is ",self.Branch)
Object=Student("Prabhakar",527,"CSE")
Object.Method() """
# Out:
# Hello WOrld
# The Name of the Student is  Prabhakar
# The Student Roll Number is  527
# The Student Branch is  CSE
